# %% [markdown]
# <a href="https://colab.research.google.com/github/soyeunju/ESAA/blob/main/ESAA_0920_Week3_Fri_Session_scores_Exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Scores

# %% [markdown]
# ### Introduction:
#
# This time you will create the data.
#
# ***Exercise based on [Chris Albon](http://chrisalbon.com/) work, the credits belong to him.***
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Step 2. Create the DataFrame that should look like the one below.
# *참고*
#
# ```
# raw_data = {'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'],
#             'last_name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze'],
#             'female': [0, 1, 1, 0, 1],
#             'age': [42, 52, 36, 24, 73],
#             'preTestScore': [4, 24, 31, 2, 3],
#             'postTestScore': [25, 94, 57, 62, 70]}
# ```

# %%
# 딕셔너리의 키가 DataFrame의 열 이름(column name)으로 사용되고, 해당 키에 매핑된 값들이 그 열의 데이터로 들어가게 됨
raw_data = {'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'],
            'last_name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze'],
            'female': [0, 1, 1, 0, 1],
            'age': [42, 52, 36, 24, 73],
            'preTestScore': [4, 24, 31, 2, 3],
            'postTestScore': [25, 94, 57, 62, 70]}
df=pd.DataFrame(raw_data)
df
# Out:
#   first_name last_name  female  age  preTestScore  postTestScore
# 0      Jason    Miller       0   42             4             25
# 1      Molly  Jacobson       1   52            24             94
# 2       Tina       Ali       1   36            31             57
# 3       Jake    Milner       0   24             2             62
# 4        Amy     Cooze       1   73             3             70

# %% [markdown]
# ### Step 3. Create a Scatterplot of preTestScore and postTestScore, with the size of each point determined by age
# #### Hint: Don't forget to place the labels

# %%
# ?plt.scatter

# %%
plt.scatter(df.preTestScore, df.postTestScore, s=df.age)

# labels / title
plt.title('preTestScore / postTestScore')
plt.xlabel('preTestScore')
plt.ylabel('postTestScore')

plt.show()

# %% [markdown]
# ### Step 4. Create a Scatterplot of preTestScore and postTestScore.
# ### This time the size should be 4.5 times the postTestScore and the color determined by sex

# %%
plt.scatter(df.preTestScore, df.postTestScore, s=df.postTestScore*4.5, c=df.female)

#labels / title
plt.title("preTestScore / postTestScore")
plt.xlabel('preTestScore')
plt.ylabel('postTestScore')

plt.show()

# %% [markdown]
# ### BONUS: Create your own question and answer it.

# %% [markdown]
# 점수가 가장 많이 향상된 사람은?

# %%
df['score_improvement'] = df['postTestScore'] - df['preTestScore']
df
# Out:
#   first_name last_name  female  age  preTestScore  postTestScore  \
# 0      Jason    Miller       0   42             4             25
# 1      Molly  Jacobson       1   52            24             94
# 2       Tina       Ali       1   36            31             57
# 3       Jake    Milner       0   24             2             62
# 4        Amy     Cooze       1   73             3             70
#
#    score_improvement
# 0                 21
# 1                 70
# 2                 26
# 3                 60
# 4                 67

# %%
max_improvement_person = df.iloc[df['score_improvement'].idxmax()]
max_improvement_person
# Out:
# first_name              Molly
# last_name            Jacobson
# female                      1
# age                        52
# preTestScore               24
# postTestScore              94
# score_improvement          70
# Name: 1, dtype: object
